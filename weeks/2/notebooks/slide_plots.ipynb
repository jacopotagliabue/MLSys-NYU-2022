# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
import numpy as np
import pandas as pd

# %config InlineBackend.figure_format = "retina"

# %%
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["axes.titlesize"] = 18

# %%
np.random.seed(666)

# %%
def comparison_plot(actual, predicted):
    """Convenience function to plot actual vs. predicted home prices"""
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.scatter(actual, predicted)
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")
    ax.set_title("Home Price Predictions")
    
    formatter = lambda x, pos: f"${int(x/1000):,}K"
    ax.xaxis.set_major_formatter(formatter)
    ax.yaxis.set_major_formatter(formatter)
    
    # Make the axis limits equal so that the figure
    # is perfectly square.
    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()
    
    lim = (min(xmin, ymin), max(xmax, ymax))
    ax.set_xlim(lim)
    ax.set_ylim(lim)

# %%
# Generate fake data assuming constant prediction error.
actual = np.random.randint(50_000, 1_000_000, 501)
predicted = actual + np.random.normal(0, 50_000, len(actual))

# %%
comparison_plot(actual, predicted)
